# %% [markdown]
# ## Práctica parte FastAPI

# %% [markdown]
# En esta práctica y este parte sobre FastAPI, se requiere desarrollar un script que contenga al menos 5 módulos app.get, de los cuales dos deben ser pipelines de Hugging Face (HF). Como parte de la entrega, se deberán proporcionar varias capturas de pantalla que demuestren el avance y la funcionalidad del trabajo realizado.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image1.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image2.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image3.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image4.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image5.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image6.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread(r'C:\Users\theot\Desktop\Practica despiegle\Fastapi\image8.png')

plt.figure(figsize=(20, 16))

plt.imshow(img)
plt.axis('off')
plt.show()
